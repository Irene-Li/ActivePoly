# %%
import numpy as np
from scipy.integrate import solve_ivp
from matplotlib import pyplot as plt
from utils import *

def corr_h(omegas): 
    return 1/((a*b-omegas**2)**2 + omegas**2*(a + b - c)**2)

# %%
a = 0.01
b = 1
c = 1
d = 0.1
J = np.array([[-a, c], [-d, -b]])
eigs = np.linalg.eig(J)
print(eigs)

def rhs(t, y): 
    return J @ y 


T = int(1e2) 
t_eval = np.linspace(0, T, 100)
res = solve_ivp(rhs, [0, T], [1, 1], method='LSODA', t_eval=t_eval)

plt.plot(res.y[0], label='h')
plt.plot(res.y[1], label='p')
plt.xlim([0, 100])
plt.legend()
plt.show()
# Out:
# (array([-0.12417852, -0.88582148]), array([[ 0.99354468, -0.75227036],
#        [-0.11344146,  0.65885454]]))

# %%
D = 1
a = 0.0005
b = 0.1
c = 0.1
d = 0

def _update(y, dt): 
    y[0] += (- a*y[0] + c*y[1])*dt
    y[1] += (- b*y[1] - d*y[0])*dt + np.sqrt(2*D*dt)*np.random.normal()


T = 1e3
dt = 1e-2
n_frames = int(1*T) 

n_repeats = 10
results = [] 
for n in range(n_repeats): 

    y = np.zeros((2))
    res = np.zeros((n_frames, 2))
    for i in range(n_frames):
        for j in range(int(T/n_frames/dt)):
            _update(y, dt)
        res[i] = np.copy(y)
    res[:, 0] = rescale(res[:, 0])
    res[:, 1] = rescale(res[:, 1]) #+ 0.1*np.random.normal(size=n_frames)
    results.append(res)
results = np.array(results)

# %%
plt.plot(res[:, 1], label='p')
plt.plot(res[:, 0], label='h')
plt.legend() 
plt.show()

# %%
p = results[:, :, 1]
h = results[:, :, 0]

def corr(x, y):
    return np.mean(np.einsum('ij, ik->ijk', x, y), axis=0)
    

p_corr = corr(p, p)
h_corr = corr(h, h)
cross_corr = corr(h, p)

plt.imshow(p_corr)
plt.show() 

plt.imshow(h_corr)
plt.show() 

plt.imshow(cross_corr)
plt.show()

# %%
def mean_corr(corr): 
    corr_tau = [np.mean(np.diagonal(corr, f)) for f in np.arange(0, n_frames)] 
    return corr_tau 

p_corr_m = mean_corr(p_corr)
h_corr_m = mean_corr(h_corr)
cross_corr_m = mean_corr(cross_corr) 

t = np.arange(n_frames, 0, -1)

for res in results: 
    h = res[:, 0]
    p = res[:, 1]
    plt.plot(t, find_auto_corr(h), '--', alpha=0.3, color='b')
    plt.plot(t, find_auto_corr(p), '--', alpha=0.3, color='orange')
    plt.plot(t, find_corr(h, p), '--', alpha=0.3, color='green')

f = lambda x, y: find_corr(rescale(x), rescale(y))
plt.plot(t, np.mean([f(res[:, 0], res[:, 0]) for res in results], axis=0), color='b', label='h auto corr')
plt.plot(t, np.mean([f(res[:, 1], res[:, 1]) for res in results], axis=0), color='orange', label='p auto corr')
plt.plot(t, np.mean([f(res[:, 0], res[:, 1]) for res in results], axis=0), color='green', label='h, p cross corr')
plt.legend()
plt.xlabel('t')
plt.xlim([0, n_frames])
plt.ylim([-1, 1])
plt.title('correlations in time')
plt.show()

# %%
fig, axs = plt.subplots(1, 4, sharex=True, figsize=(15, 5))

omegas = np.fft.fftfreq(n_frames)*2*np.pi
for res in results: 
    axs[0].plot(omegas, (np.abs(np.fft.fft(res[:, 0]))**2), 'o--', alpha=0.5, color='orange')
    axs[1].plot(omegas, (np.abs(np.fft.fft(res[:, 1]))**2), 'o--', alpha=0.5, color='orange') 
    
    cross_corr = np.conj(np.fft.fft(res[:, 0]))*np.fft.fft(res[:, 1])
    axs[2].plot(omegas, cross_corr.real, 'o--', alpha=0.2, color='orange')
    axs[3].plot(omegas, cross_corr.imag, 'o--', alpha=0.2, color='orange')
    

h_omega = np.fft.fft(results[:, :, 0])
p_omega = np.fft.fft(results[:, :, 1])
corr_h_sim = np.mean(np.abs(h_omega)**2, axis=0)
corr_p_sim = np.mean(np.abs(p_omega)**2, axis=0)
cross_corr = np.mean(np.conj(h_omega)*p_omega, axis=0)
axs[0].plot(omegas, corr_h_sim, color='red', label='mean of simulation')
axs[0].legend()
axs[0].set_title('h auto corr')


axs[1].plot(omegas, corr_p_sim, color='red', label='mean of simulation')
axs[1].set_title('p auto corr')
axs[2].plot(omegas, cross_corr.real, color='red')
axs[3].plot(omegas, cross_corr.imag, color='red')

axs[2].set_title('cross corr real')
axs[3].set_title('cross corr imag')


axs[0].set_xlim([0, max(omegas[:50])])
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 3, sharex=True, figsize=(15, 5))

axs[0].plot(np.fft.ifft(corr_h_sim).real/n_frames, label='fft')
axs[0].plot(h_corr_m, label='time series')
axs[0].legend() 
axs[0].set_xlim([0, 1000])

axs[1].plot(np.fft.ifft(corr_p_sim).real/n_frames, label='fft')
axs[1].plot(p_corr_m, label='time series')
axs[1].legend() 

axs[2].plot(np.fft.ifft(cross_corr).real/n_frames, label='fft')
axs[2].plot(cross_corr_m, label='time series')
axs[2].legend() 

plt.tight_layout()
plt.show()

# %%
omegas = np.linspace(0, 0.6, 100)
corr = corr_h(omegas)

plt.plot(omegas, np.sqrt(corr))
plt.show()
